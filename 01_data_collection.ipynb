# %% [markdown]
# # Taylor Swift Discography: Part I - Data Collection
#
# ## Introduction
#
# This notebook is the first in a series of notebooks analyzing Taylor Swift's discography; in this notebook, I collect and compile data using [parsel](https://parsel.readthedocs.io/en/latest/) to webscrape from [Genius](https://genius.com/), an online music encyclopedia. From there, I use pandas for dataframe creation and SQLite3 for database creation.
#
# It should be noted that Genius does have an [API](https://docs.genius.com/) for application development. However, song lyrics are not made available via API, which is a crucial component of this project. A third-party Python package, [lyricsgenius](https://lyricsgenius.readthedocs.io/en/master/), is available to work in tandem with the API, webscraping on the user's behalf. I tested both the API and lyricsgenius as resources before ultimately concluding to collect the data myself.
#
# The resulting dataframes and database from this notebook are available in the [data folder](./data). CSV files used in this notebook are also included in the [data folder](./data/csv).
#
# This notebook uses the modules [`genius_scrape.py`](./src/genius_scrape.py) for webscraping and discography dataframe creation and [`discog_mods.py`](./src/discog_mods.py) for additional modifications and transformations.

# %%
import pandas as pd

from src import discog_mods
from src import genius_scrape

# %% [markdown]
# ## Webscraping and Initial Dataframe
#
# Genius is very thorough in cataloguing an artist's discogrpahy, tracking all physical and digital variants of a release with different tracklists as well as singles, EPs, demo CDs, official playlists, and special releases. Therefore, Genius catalogues Taylor Swift as having over [100 different albums](https://genius.com/artists/Taylor-swift/albums), most of which contain repeated songs. For sake of processing times, I manually select the releases used to create the initial dataframe: this includes deluxe versions of original albums and "Taylor's Version" rerecordings of her studio albums are preferred, and non-album singles and streaming-specific EPs that contain previously unreleased tracks are included.
#
# The dataframe is structured as follows:
#
# * **album_title**: the title of the album (or other release) containing each song
# * **album_url**: the URL to the Genius page for the album
# * **album_era**: the musical "era" the album was released in
#   * Note: this terminology was brought about via [The Eras Tour](https://en.wikipedia.org/wiki/The_Eras_Tour) and refers to a major studio album. Songs or collaborations not associated with a Taylor Swift album are housed under the era "Other"
# * **album_track_number**: the track number for the song on the given album
# * **song_title**: the title of the song
# * **song_url**: the URL to the Genius page for the song
# * **song_artists**: the performing artist(s) for the song (returned as a list)
# * **song_lyrics**: the lyrics to the song (returned as a single string)
# * **song_writers**: the writer(s) for the song (returned as a list)
# * **song_producers**: the producers(s) for the song (returned as a list)
# * **song_tags**: the genre tag(s) for the song (returned as a list)

# %%
# Manually selected albums/EPs from Genius' list
# Maximizes the number of unique songs while reducing cleanup
albums = genius_scrape.create_dict_from_file('album_list.csv')

# %%
#Initial dataframe creation
raw_tswift = genius_scrape.create_discography('Taylor Swift', albums)
raw_tswift.to_pickle('data/taylor_swift_raw.pkl')
raw_tswift.head()
# Out:
#     album_title                                          album_url  \
# 0  Taylor Swift  https://genius.com/albums/Taylor-Swift/Taylor-...
# 1  Taylor Swift  https://genius.com/albums/Taylor-Swift/Taylor-...
# 2  Taylor Swift  https://genius.com/albums/Taylor-Swift/Taylor-...
# 3  Taylor Swift  https://genius.com/albums/Taylor-Swift/Taylor-...
# 4  Taylor Swift  https://genius.com/albums/Taylor-Swift/Taylor-...
#
#       album_era album_track_number              song_title  \
# 0  Taylor Swift                  1              Tim McGraw
# 1  Taylor Swift                  2         Picture to Burn
# 2  Taylor Swift                  3  Teardrops On My Guitar
# 3  Taylor Swift                  4   A Place In This World
# 4  Taylor Swift                  5             Cold as You
#
#                                             song_url    song_artists  \
# 0  https://genius.com/Taylor-swift-tim-mcgraw-lyrics  [Taylor Swift]
# 1  https://genius.com/Taylor-swift-picture-to-bur...  [Taylor Swift]
# 2  https://genius.com/Taylor-swift-teardrops-on-m...  [Taylor Swift]
# 3  https://genius.com/Taylor-swift-a-place-in-thi...  [Taylor Swift]
# 4  https://genius.com/Taylor-swift-cold-as-you-ly...  [Taylor Swift]
#
#                                          song_lyrics  \
# 0  He said the way my blue eyes shined Put those ...
# 1  State the obvious, I didn't get my perfect fan...
# 2  Drew looks at me I fake a smile so he won't se...
# 3  I don't know what I want, so don't ask me 'Cau...
# 4  You have a way of coming easily to me And when...
#
#                                         song_writers    song_producers  \
# 0                           [Liz Rose, Taylor Swift]  [Nathan Chapman]
# 1                           [Liz Rose, Taylor Swift]  [Nathan Chapman]
# 2                           [Liz Rose, Taylor Swift]  [Nathan Chapman]
# 3  [Angelo Petraglia, Robert Ellis Orrall, Taylor...  [Nathan Chapman]
# 4                           [Liz Rose, Taylor Swift]  [Nathan Chapman]
#
#                                            song_tags
# 0  [Country, Country Rock, American Folk, Folk, B...
# 1  [Pop, Rock, Country, Country Rock, Pop-Punk, P...
# 2  [Country, Adult Contemporary, American Folk, A...
# 3  [Country, Pop, Teen Pop, Country Pop, Soundtra...
# 4  [Country, Pop, Ballad, Country Pop, Singer-Son...

# %% [markdown]
# ## Data Cleaning and Additional Entries
#
# Like I said previously, many of Taylor Swift's releases contain repeating songs. For example, the streaming-specific EP, *The More Lover Chapter*, contains five songs: four songs are also on the standard release of the parent album, *Lover*, while only one song is a unique release. There are also numerous remixes and alternative versions of the same songs that are still the same lyrically. Both these remixes and repeated songs need to be removed from the dataframe; the latter can be easily filtered out while the former requires some manual work. Remixes or versions of songs that include new features, such "Karma (Remix) (Ft. Ice Spice)," are included for the sake of tracking collaborations, though they will be removed later in the project.
#
# Taylor also has several songs that she wrote for movies or cowrote/performed with other artists that ultimately don't end up one of her releases. Those albums weren't included in the initial data pull as to not require more cleanup after the fact. Those songs get added into the dataframe individually.
#
# Another small change I make is reverting instances of "Joe Alwyn" in both `song_writers` and `song_producers` to "William Bowery," the original pseudonym used for these writing/producing credits. This is a personal preference, as I'd like the William Bowery song credits to be consistent across albums/eras.

# %%
# Drops specific songs (alternative productions/remixes of existing songs)
# and duplicate songs
tswift = discog_mods.drop_songs_from_file(raw_tswift, 'songs_to_drop_part1.csv', drop_duplicates=True)
tswift['album_era'].value_counts()
# Out:
# album_era
# Red (TV)          32
# Fearless (TV)     26
# Midnights         23
# Speak Now (TV)    22
# 1989 (TV)         22
# Red               20
# Lover             19
# Fearless          18
# Speak Now         17
# folklore          17
# evermore          17
# 1989              16
# reputation        15
# Taylor Swift      14
# Other              2
# Name: count, dtype: int64

# %%
# Adds numerous songs to the dataframe at once
tswift = discog_mods.add_songs_from_file(tswift, 'songs_to_add.csv')
tswift.tail(15)
# Out:
#                                         album_title  \
# 290          How Long Do You Think It’s Gonna Last?
# 291                                            Shea
# 292                 Kellie Pickler (Deluxe Edition)
# 293                                     The Breaker
# 294           NOW That’s What I Call Music! 56 [US]
# 295                1989 (Taylor’s Version) [Deluxe]
# 296                                          Bigger
# 297       Two Lanes of Freedom (Accelerated Deluxe)
# 298                                  Battle Studies
# 299       Women in Music Pt. III (Expanded Edition)
# 300                                            None
# 301                                            None
# 302           NOW That’s What I Call Music! 73 [US]
# 303                       = (Equals) (Tour Edition)
# 304  Speak Now: World Tour Live (Brazilian Edition)
#
#                                              album_url  album_era  \
# 290  https://genius.com/albums/Big-red-machine/How-...      Other
# 291         https://genius.com/albums/Shea-fisher/Shea      Other
# 292  https://genius.com/albums/Kellie-pickler/Kelli...      Other
# 302  We could leave the Christmas lights up 'til Ja...
# 303  How was I to know? It's a crazy thing I showed...
# 304  Lembrei desse sentimento Gritando dentro de nó...
#
#                                           song_writers  \
# 290                      [Aaron Dessner, Taylor Swift]
# 291                      [Taylor Swift, Brett Beavers]
# 292                     [Taylor Swift, Kellie Pickler]
# 293                                     [Taylor Swift]
# 294  [Shellback, Max Martin, Kendrick Lamar, Taylor...
# 295  [Taylor Swift, Max Martin, Shellback, Kendrick...
# 296                        [Pat Monahan, Taylor Swift]
# 297  [Brett Warren, Brad Warren, Josh Kear, Mark Ir...
# 298                                       [John Mayer]
# 299  [Ariel Rechtshaid, Este Haim, Alana Haim, Rost...
# 300  [B.o.B, Taylor Swift, Cirkut, Dr. Luke, Ammar ...
# 301                        [Joel Little, Taylor Swift]
# 302         [Scott Harris, Shawn Mendes, Taylor Swift]
# 303  [Taylor Swift, Fred again.., Johnny McDaid, RØ...
# 304                    [Paula Fernandes, Taylor Swift]
#
#                                         song_producers  \
# 290                                    [Aaron Dessner]
# 291                                    [Brett Beavers]
# 292                                    [Chris Lindsey]
# 293                                        [Jay Joyce]
# 294                      [ILYA, Shellback, Max Martin]
# 295                   [Christopher Rowe, Taylor Swift]
# 296  [Kristian Bush, Julian Raymond, Jennifer Nettles]
# 297                      [Tim McGraw, Byron Gallimore]
# 298                         [John Mayer, Steve Jordan]
# 299          [Danielle Haim, Ariel Rechtshaid, Rostam]
# 300                                 [Cirkut, Dr. Luke]
# 301                        [Joel Little, Taylor Swift]
# 302                      [Taylor Swift, Jack Antonoff]
# 303  [RØMANS, Johnny McDaid, Ed Sheeran, Fred again..]
# 304                                  [Márcio Monteiro]
#
#                                              song_tags
# 290  [Rock, Adult Contemporary, Alternative Pop, Fo...
# 291                                          [Country]
# 292                 [Country, Rock, Singer-Songwriter]
# 293  [Country, Cover, Piano, Country Pop, Ballad, A...
# 294  [Rap, Pop, Dance-Pop, Diss, Electronic, Remix,...
# 295  [R&B, Rap, Pop, Electronic, Adult Contemporary...
# 296  [Country, Pop, Adult Contemporary, Duet, Balla...
# 297        [Country, Rock, Country Rock, Duet, Ballad]
# 298  [Rock, Country Rock, Duet, Soft Rock, Adult Co...
# 299  [Rock, Country, Pop, Alternative Pop, Alternat...
# 300                            [Pop, Rap, Country Rap]
# 301  [Pop, Synth-Pop, Electronic, Protest Songs, El...
# 302  [Country, Pop, Canada, Duet, Singer-Songwriter...
# 303  [Pop, Adult Contemporary, Duet, Singer-Songwri...
# 304  [Country, Pop, Duet, Remix, Concert, Live, Ser...

# %%
# Changing instances of 'Joe Alwyn' to 'William Bowery'
tswift['song_writers'] = discog_mods.change_credit_name(tswift['song_writers'], 'Joe Alwyn', 'William Bowery')
tswift['song_producers'] = discog_mods.change_credit_name(tswift['song_producers'], 'Joe Alwyn', 'William Bowery')

# %% [markdown]
# ## Database Creation and Exporting
#
# At this point, the dataframe is complete and ready to be used in later notebooks. However, I also want a database version of the dataframe so I can query via SQL. Using SQLite3, I convert the dataframe into a six-table database, the schema of which can be seen here (courtesy of [dbdiagram.io](https://dbdiagram.io/)):
#
# ![db_schema.png](./figures/db_schema.png)

# %%
# Export dataframe to pkl
tswift.to_pickle('data/taylor_swift_clean.pkl')

# Creates database
discog_mods.convert_to_db(tswift,'taylor_swift.db')
